# %%
import matplotlib.pyplot as plt
import numpy as np
import os, shutil
import os
import numpy as np
import pandas as pd
import itertools
import seaborn as sns

from keras import models
from keras import layers
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
from shutil import copy2

from keras.applications import inception_v3
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.metrics import confusion_matrix, f1_score
from keras.models import Model
from sklearn.model_selection import train_test_split


np.random.seed(123)

# %%
# # Set up data into train and test directories with folders of bobcat and not_bobcat
# train_data_dir = '/Users/j.markdaniels/Downloads/final_proj_data/bobcat_cougar_data/train/'#348 bobcat, 340 not_bobcat
# test_data_dir = '/Users/j.markdaniels/Downloads/final_proj_data/bobcat_cougar_data/test/'#348 bobcat, 340 not_bobcat



# train_data_dir = '/Users/j.markdaniels/Desktop/Data/multiclass/train/'
# test_data_dir = '/Users/j.markdaniels/Desktop/Data/multiclass/test/'

# test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
#         test_data_dir, 
#         target_size=(128, 128), batch_size=340)

# train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
#         train_data_dir, 
#         target_size=(128, 128), batch_size=340)

# # create the data sets
# train_images, train_labels = next(train_generator)
# test_images, test_labels = next(test_generator)

# train_generator.classes

# get all the data in the directory split/test, and reshape them

# %%
data_te = ImageDataGenerator(rescale=1./255).flow_from_directory( 
        '/Users/j.markdaniels/Desktop/Data/multiclass/test/', 
        target_size=(224, 224), 
        batch_size = 2776, 
        class_mode='categorical',
        seed = 123)

data_tr = ImageDataGenerator(rescale=1./255).flow_from_directory( 
        '/Users/j.markdaniels/Desktop/Data/multiclass/train/', 
        target_size=(224, 224), 
        batch_size = 340, 
        class_mode='categorical',
        seed = 123) 

labels_tr.shape
# Out:
# Found 2776 images belonging to 20 classes.
# Found 11179 images belonging to 20 classes.
# (340, 20)

# %%
#split images and labels
images_tr, labels_tr = next(data_tr)
# Out:
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 85 bytes but only got 0. Skipping tag 33285
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 93 bytes but only got 0. Skipping tag 33285
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 141 bytes but only got 0. Skipping tag 37386
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 149 bytes but only got 0. Skipping tag 37381
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 157 bytes but only got 0. Skipping tag 37381
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 144 bytes but only got 0. Skipping tag 40964
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 192 bytes but only got 0. Skipping tag 40964
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 192 bytes but only got 0. Skipping tag 41735
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 62 bytes but only got 0. Skipping tag 41989
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 16908320 bytes but only got 8068. Skipping tag 2048
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 16908320 bytes but only got 8036. Skipping tag 2048
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 34209794 bytes but only got 8258. Skipping tag 2048
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 68157444 bytes but only got 8276. Skipping tag 2304
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 34078722 bytes but only got 8193. Skipping tag 1536
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 34078722 bytes but only got 8105. Skipping tag 1024
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 68157442 bytes but only got 8126. Skipping tag 768
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 136315212 bytes but only got 8268. Skipping tag 1280
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 135004164 bytes but only got 8023. Skipping tag 3584
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 270008328 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 135004164 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 50528257 bytes but only got 8074. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 50528257 bytes but only got 8278. Skipping tag 256
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 101056514 bytes but only got 8081. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 202113028 bytes but only got 8056. Skipping tag 256
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 405274632 bytes but only got 8182. Skipping tag 256
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 50528257 bytes but only got 8278. Skipping tag 6656
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 101056514 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 404226064 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 302186498 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 302186497 bytes but only got 8198. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 605290498 bytes but only got 8090. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1208745988 bytes but only got 8278. Skipping tag 6656
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2418540552 bytes but only got 8078. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 302186497 bytes but only got 8278. Skipping tag 6656
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 302186497 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 604372994 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2417491976 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65537 bytes but only got 0. Skipping tag 1
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393222 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 8278. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6553646 bytes but only got 0. Skipping tag 4608
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3221260288 bytes but only got 0. Skipping tag 2072
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 268435640 bytes but only got 0. Skipping tag 768
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 4718640 bytes but only got 0. Skipping tag 2560
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 458765 bytes but only got 0. Skipping tag 23
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1441794 bytes but only got 8278. Skipping tag 161
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65575 bytes but only got 0. Skipping tag 55
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393219 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 13369600 bytes but only got 0. Skipping tag 180
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:763: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2080374824 bytes but only got 8278. Skipping tag 256
#   " Skipping tag %s" % (size, len(data), tag))
# /anaconda3/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:780: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 0.
#   warnings.warn(str(msg))
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py:968: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +

# %%
#split images and labels
images_te, labels_te = next(data_te)

# %%
# images = np.concatenate((images_tr, images_te))

# %%
# labels_tr

# %%
#labels = np.concatenate((labels_tr, labels_te), axis =0 )

# %%
#labels.shape

# %%
# X_model, X_test, y_model, y_test = train_test_split(images, labels, test_size=0.20, random_state=123)

# %%
X_train, X_val, y_train, y_val = train_test_split(images_tr, labels_tr, test_size=0.20, random_state=123)

# %%
y_test  = labels_te

# %%
y_test.shape
# Out:
# (2776, 20)

# %%
X_test = images_te

# %%
X_test.shape
# Out:
# (2776, 224, 224, 3)

# %%
imagenet=inception_v3.InceptionV3(weights='imagenet',include_top=False)
imagenet_new=imagenet.output
new_model = models.Sequential()
new_model.add(imagenet)
new_model.add(GlobalAveragePooling2D())
new_model.add(Dense(1024,activation='relu'))
new_model.add(Dense(1024,activation='relu')) #dense layer 2
new_model.add(Dense(512,activation='relu')) #dense layer 3
new_model.add(Dense(20,activation='softmax')) #final layer with softmax activation

# %%
for i,layer in enumerate(imagenet.layers):
  print(i,layer.name, layer.trainable)
# Out:
# 0 input_5 False
# 1 conv2d_377 True
# 2 batch_normalization_377 True
# 3 activation_377 True
# 4 conv2d_378 True
# 5 batch_normalization_378 True
# 6 activation_378 True
# 7 conv2d_379 True
# 8 batch_normalization_379 True
# 9 activation_379 True
# 10 max_pooling2d_17 True
# 11 conv2d_380 True
# 12 batch_normalization_380 True
# 13 activation_380 True
# 14 conv2d_381 True
# 15 batch_normalization_381 True
# 16 activation_381 True
# 17 max_pooling2d_18 True
# 18 conv2d_385 True
# 19 batch_normalization_385 True
# 20 activation_385 True
# 21 conv2d_383 True
# 22 conv2d_386 True
# 23 batch_normalization_383 True
# 24 batch_normalization_386 True
# 25 activation_383 True
# 26 activation_386 True
# 27 average_pooling2d_37 True
# 28 conv2d_382 True
# 29 conv2d_384 True
# 30 conv2d_387 True
# 31 conv2d_388 True
# 32 batch_normalization_382 True
# 33 batch_normalization_384 True
# 34 batch_normalization_387 True
# 35 batch_normalization_388 True
# 36 activation_382 True
# 37 activation_384 True
# 38 activation_387 True
# 39 activation_388 True
# 40 mixed0 True
# 41 conv2d_392 True
# 42 batch_normalization_392 True
# 43 activation_392 True
# 44 conv2d_390 True
# 45 conv2d_393 True
# 46 batch_normalization_390 True
# 47 batch_normalization_393 True
# 48 activation_390 True
# 49 activation_393 True
# 50 average_pooling2d_38 True
# 51 conv2d_389 True
# 52 conv2d_391 True
# 53 conv2d_394 True
# 54 conv2d_395 True
# 55 batch_normalization_389 True
# 56 batch_normalization_391 True
# 57 batch_normalization_394 True
# 58 batch_normalization_395 True
# 59 activation_389 True
# 60 activation_391 True
# 61 activation_394 True
# 62 activation_395 True
# 63 mixed1 True
# 64 conv2d_399 True
# 65 batch_normalization_399 True
# 66 activation_399 True
# 67 conv2d_397 True
# 68 conv2d_400 True
# 69 batch_normalization_397 True
# 70 batch_normalization_400 True
# 71 activation_397 True
# 72 activation_400 True
# 73 average_pooling2d_39 True
# 74 conv2d_396 True
# 75 conv2d_398 True
# 76 conv2d_401 True
# 77 conv2d_402 True
# 78 batch_normalization_396 True
# 79 batch_normalization_398 True
# 80 batch_normalization_401 True
# 81 batch_normalization_402 True
# 82 activation_396 True
# 83 activation_398 True
# 84 activation_401 True
# 85 activation_402 True
# 86 mixed2 True
# 87 conv2d_404 True
# 88 batch_normalization_404 True
# 89 activation_404 True
# 90 conv2d_405 True
# 91 batch_normalization_405 True
# 92 activation_405 True
# 93 conv2d_403 True
# 94 conv2d_406 True
# 95 batch_normalization_403 True
# 96 batch_normalization_406 True
# 97 activation_403 True
# 98 activation_406 True
# 99 max_pooling2d_19 True
# 100 mixed3 True
# 101 conv2d_411 True
# 102 batch_normalization_411 True
# 103 activation_411 True
# 104 conv2d_412 True
# 105 batch_normalization_412 True
# 106 activation_412 True
# 107 conv2d_408 True
# 108 conv2d_413 True
# 109 batch_normalization_408 True
# 110 batch_normalization_413 True
# 111 activation_408 True
# 112 activation_413 True
# 113 conv2d_409 True
# 114 conv2d_414 True
# 115 batch_normalization_409 True
# 116 batch_normalization_414 True
# 117 activation_409 True
# 118 activation_414 True
# 119 average_pooling2d_40 True
# 120 conv2d_407 True
# 121 conv2d_410 True
# 122 conv2d_415 True
# 123 conv2d_416 True
# 124 batch_normalization_407 True
# 125 batch_normalization_410 True
# 126 batch_normalization_415 True
# 127 batch_normalization_416 True
# 128 activation_407 True
# 129 activation_410 True
# 130 activation_415 True
# 131 activation_416 True
# 132 mixed4 True
# 133 conv2d_421 True
# 134 batch_normalization_421 True
# 135 activation_421 True
# 136 conv2d_422 True
# 137 batch_normalization_422 True
# 138 activation_422 True
# 139 conv2d_418 True
# 140 conv2d_423 True
# 141 batch_normalization_418 True
# 142 batch_normalization_423 True
# 143 activation_418 True
# 144 activation_423 True
# 145 conv2d_419 True
# 146 conv2d_424 True
# 147 batch_normalization_419 True
# 148 batch_normalization_424 True
# 149 activation_419 True
# 150 activation_424 True
# 151 average_pooling2d_41 True
# 152 conv2d_417 True
# 153 conv2d_420 True
# 154 conv2d_425 True
# 155 conv2d_426 True
# 156 batch_normalization_417 True
# 157 batch_normalization_420 True
# 158 batch_normalization_425 True
# 159 batch_normalization_426 True
# 160 activation_417 True
# 161 activation_420 True
# 162 activation_425 True
# 163 activation_426 True
# 164 mixed5 True
# 165 conv2d_431 True
# 166 batch_normalization_431 True
# 167 activation_431 True
# 168 conv2d_432 True
# 169 batch_normalization_432 True
# 170 activation_432 True
# 171 conv2d_428 True
# 172 conv2d_433 True
# 173 batch_normalization_428 True
# 174 batch_normalization_433 True
# 175 activation_428 True
# 176 activation_433 True
# 177 conv2d_429 True
# 178 conv2d_434 True
# 179 batch_normalization_429 True
# 180 batch_normalization_434 True
# 181 activation_429 True
# 182 activation_434 True
# 183 average_pooling2d_42 True
# 184 conv2d_427 True
# 185 conv2d_430 True
# 186 conv2d_435 True
# 187 conv2d_436 True
# 188 batch_normalization_427 True
# 189 batch_normalization_430 True
# 190 batch_normalization_435 True
# 191 batch_normalization_436 True
# 192 activation_427 True
# 193 activation_430 True
# 194 activation_435 True
# 195 activation_436 True
# 196 mixed6 True
# 197 conv2d_441 True
# 198 batch_normalization_441 True
# 199 activation_441 True
# 200 conv2d_442 True
# 201 batch_normalization_442 True
# 202 activation_442 True
# 203 conv2d_438 True
# 204 conv2d_443 True
# 205 batch_normalization_438 True
# 206 batch_normalization_443 True
# 207 activation_438 True
# 208 activation_443 True
# 209 conv2d_439 True
# 210 conv2d_444 True
# 211 batch_normalization_439 True
# 212 batch_normalization_444 True
# 213 activation_439 True
# 214 activation_444 True
# 215 average_pooling2d_43 True
# 216 conv2d_437 True
# 217 conv2d_440 True
# 218 conv2d_445 True
# 219 conv2d_446 True
# 220 batch_normalization_437 True
# 221 batch_normalization_440 True
# 222 batch_normalization_445 True
# 223 batch_normalization_446 True
# 224 activation_437 True
# 225 activation_440 True
# 226 activation_445 True
# 227 activation_446 True
# 228 mixed7 True
# 229 conv2d_449 True
# 230 batch_normalization_449 True
# 231 activation_449 True
# 232 conv2d_450 True
# 233 batch_normalization_450 True
# 234 activation_450 True
# 235 conv2d_447 True
# 236 conv2d_451 True
# 237 batch_normalization_447 True
# 238 batch_normalization_451 True
# 239 activation_447 True
# 240 activation_451 True
# 241 conv2d_448 True
# 242 conv2d_452 True
# 243 batch_normalization_448 True
# 244 batch_normalization_452 True
# 245 activation_448 True
# 246 activation_452 True
# 247 max_pooling2d_20 True
# 248 mixed8 True
# 249 conv2d_457 True
# 250 batch_normalization_457 True
# 251 activation_457 True
# 252 conv2d_454 True
# 253 conv2d_458 True
# 254 batch_normalization_454 True
# 255 batch_normalization_458 True
# 256 activation_454 True
# 257 activation_458 True
# 258 conv2d_455 True
# 259 conv2d_456 True
# 260 conv2d_459 True
# 261 conv2d_460 True
# 262 average_pooling2d_44 True
# 263 conv2d_453 True
# 264 batch_normalization_455 True
# 265 batch_normalization_456 True
# 266 batch_normalization_459 True
# 267 batch_normalization_460 True
# 268 conv2d_461 True
# 269 batch_normalization_453 True
# 270 activation_455 True
# 271 activation_456 True
# 272 activation_459 True
# 273 activation_460 True
# 274 batch_normalization_461 True
# 275 activation_453 True
# 276 mixed9_0 True
# 277 concatenate_9 True
# 278 activation_461 True
# 279 mixed9 True
# 280 conv2d_466 True
# 281 batch_normalization_466 True
# 282 activation_466 True
# 283 conv2d_463 True
# 284 conv2d_467 True
# 285 batch_normalization_463 True
# 286 batch_normalization_467 True
# 287 activation_463 True
# 288 activation_467 True
# 289 conv2d_464 True
# 290 conv2d_465 True
# 291 conv2d_468 True
# 292 conv2d_469 True
# 293 average_pooling2d_45 True
# 294 conv2d_462 True
# 295 batch_normalization_464 True
# 296 batch_normalization_465 True
# 297 batch_normalization_468 True
# 298 batch_normalization_469 True
# 299 conv2d_470 True
# 300 batch_normalization_462 True
# 301 activation_464 True
# 302 activation_465 True
# 303 activation_468 True
# 304 activation_469 True
# 305 batch_normalization_470 True
# 306 activation_462 True
# 307 mixed9_1 True
# 308 concatenate_10 True
# 309 activation_470 True
# 310 mixed10 True

# %%
for i,layer in enumerate(new_model.layers):
  print(i,layer.name, layer.trainable)
# Out:
# 0 inception_v3 True
# 1 global_average_pooling2d_4 True
# 2 dense_13 True
# 3 dense_14 True
# 4 dense_15 True
# 5 dense_16 True

# %%
for layer in new_model.layers[:1]:
    layer.trainable=False

# %%
for i,layer in enumerate(new_model.layers):
  print(i,layer.name, layer.trainable)
# Out:
# 0 inception_v3 False
# 1 global_average_pooling2d_4 True
# 2 dense_13 True
# 3 dense_14 True
# 4 dense_15 True
# 5 dense_16 True

# %%
y_val.shape
# Out:
# (68, 20)

# %%
new_model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# step_size_train=train_generator.n//train_generator.batch_size
new_model.fit(X_train,
          y_train,
          epochs=100,
          batch_size=60,
          validation_data=(X_val, y_val))
# Out:
# Train on 435 samples, validate on 109 samples
# Epoch 1/100
# 435/435 [==============================] - 56s 128ms/step - loss: 0.3111 - acc: 0.8920 - val_loss: 3.0882 - val_acc: 0.6147
# Epoch 2/100
# 435/435 [==============================] - 36s 83ms/step - loss: 0.3347 - acc: 0.8989 - val_loss: 2.3989 - val_acc: 0.5963
# Epoch 3/100
# 435/435 [==============================] - 36s 83ms/step - loss: 0.1576 - acc: 0.9609 - val_loss: 2.7731 - val_acc: 0.6239
# Epoch 4/100
# 435/435 [==============================] - 36s 83ms/step - loss: 0.1194 - acc: 0.9609 - val_loss: 2.9539 - val_acc: 0.6055
# Epoch 5/100
# 435/435 [==============================] - 36s 84ms/step - loss: 0.2217 - acc: 0.9517 - val_loss: 2.5764 - val_acc: 0.6330
# Epoch 6/100
# 435/435 [==============================] - 36s 84ms/step - loss: 0.1123 - acc: 0.9609 - val_loss: 2.7121 - val_acc: 0.6514
# Epoch 7/100
# 435/435 [==============================] - 37s 84ms/step - loss: 0.0318 - acc: 0.9885 - val_loss: 3.1490 - val_acc: 0.6239
# Epoch 8/100
# 435/435 [==============================] - 36s 82ms/step - loss: 0.0434 - acc: 0.9839 - val_loss: 2.8728 - val_acc: 0.6606
# Epoch 9/100
# 435/435 [==============================] - 37s 85ms/step - loss: 0.0436 - acc: 0.9816 - val_loss: 2.6416 - val_acc: 0.6881
# Epoch 10/100
# 435/435 [==============================] - 37s 84ms/step - loss: 0.0635 - acc: 0.9839 - val_loss: 3.8154 - val_acc: 0.5963
# Epoch 11/100
# 435/435 [==============================] - 37s 84ms/step - loss: 0.0692 - acc: 0.9793 - val_loss: 3.3055 - val_acc: 0.6606
# Epoch 12/100
# 435/435 [==============================] - 36s 83ms/step - loss: 0.
100
# 435/435 [==============================] - 35s 81ms/step - loss: 0.0136 - acc: 0.9977 - val_loss: 3.3766 - val_acc: 0.6606
# Epoch 96/100
# 435/435 [==============================] - 35s 81ms/step - loss: 0.0048 - acc: 0.9977 - val_loss: 3.6130 - val_acc: 0.6330
# Epoch 97/100
# 435/435 [==============================] - 36s 82ms/step - loss: 0.0235 - acc: 0.9908 - val_loss: 3.7180 - val_acc: 0.6606
# Epoch 98/100
# 435/435 [==============================] - 36s 83ms/step - loss: 0.0101 - acc: 0.9977 - val_loss: 4.5192 - val_acc: 0.5596
# Epoch 99/100
# 435/435 [==============================] - 36s 82ms/step - loss: 0.0686 - acc: 0.9862 - val_loss: 3.2897 - val_acc: 0.6422
# Epoch 100/100
# 435/435 [==============================] - 36s 83ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 3.4327 - val_acc: 0.6881

# %%
new_model.evaluate(X_test, y_test)
# Out:
# 136/136 [==============================] - 10s 74ms/step
# [2.8500960293938133, 0.7058823529411765]

# %%
predictions_transfer = new_model.predict(X_test)
# predictions_transfer = np.around(predictions_transfer)

# %% [markdown]
# ## Confusion Matrix from Hot Dog/Not Hot Dog

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
plt.figure()
plot_confusion_matrix(confusion_matrix(y_test, predictions_transfer), classes=['virginia_opossum',
 'raccoon',
 'coyote',
 'red_fox',
 'bald_eagle',
 'seals',
 'canada_lynx',
 'elk',
 'black_bear',
 'raven',
 'nutria',
 'gray_fox',
 'bobcat',
 'ringtail',
 'gray_wolf',
 'mountain_beaver',
 'sea_lions',
 'deer',
 'cougar',
 'columbian_black-tailed_deer'], normalize=False,
                      title='Confusion matrix - ImagenetV3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-167-cc3210e0756d> in <module>
#       1 plt.figure()
# ----> 2 plot_confusion_matrix(confusion_matrix(y_test, predictions_transfer), classes=['virginia_opossum',
#       3  'raccoon',
#       4  'coyote',
#       5  'red_fox',
#
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %% [markdown]
# ## Jon's Confusion Matrix

# %%
plt.imshow(X_test[0])

# %%
somevariable = ['seals',
 'canada_lynx',
 'elk',
 'black_bear',
 'raven',
 'nutria',
 'gray_fox',
 'bobcat',
 'ringtail',
 'gray_wolf',
 'mountain_beaver',
 'sea_lions',
 'deer',
 'cougar',
 'columbian_black-tailed_deer']
print(somevariable)
# Out:
# ['seals', 'canada_lynx', 'elk', 'black_bear', 'raven', 'nutria', 'gray_fox', 'bobcat', 'ringtail', 'gray_wolf', 'mountain_beaver', 'sea_lions', 'deer', 'cougar', 'columbian_black-tailed_deer']

# %%
y_pred = np.argmax(predictions_transfer, axis=1)

# %%
y_true = np.where(y_test != 0)[1]

# %%
labels = ['virginia_opossum','raccoon','coyote','red_fox','bald_eagle', 'seals', 'canada_lynx', 'elk', 'black_bear', 'raven', 'nutria', 'gray_fox', 'bobcat', 'ringtail', 'gray_wolf', 'mountain_beaver', 'sea_lions', 'deer', 'cougar', 'columbian_black-tailed_deer']
# Calculate Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
# classes = classes[unique_labels(y_true, y_pred)]
# Figure adjustment and heatmap plot
f = plt.figure(figsize=(20,30))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, vmax=100, cbar=False, cmap='Paired', mask=(cm==0), fmt=',.0f', linewidths=2, linecolor='grey', ); 

# labels
ax.set_xlabel('Predicted labels', fontsize=16);
ax.set_ylabel('True labels', labelpad=30, fontsize=16); 
ax.set_title('Confusion Matrix', fontsize=18); 
ax.xaxis.set_ticklabels(labels, rotation=90); 
ax.yaxis.set_ticklabels(labels, rotation=0);
ax.set_facecolor('white')

# %%
# hist_new_model = new_model.history
# loss_values = hist_new_model['loss']
# val_loss_values = hist_new_model['val_loss']
# acc_values = hist_new_model['acc'] 
# val_acc_values = hist_new_model['val_acc']


# epochs = range(1, len(loss_values) + 1)

# plt.figure(figsize=(15,4))
# plt.subplot(121)
# plt.plot(epochs, loss_values, 'g.', label='Training loss')
# plt.plot(epochs, val_loss_values, 'g', label='Validation loss')

# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()

# plt.subplot(122)
# plt.plot(epochs, acc_values, 'r.', label='Training acc')
# plt.plot(epochs, val_acc_values, 'r', label='Validation acc')
# plt.title('Training and validation accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-04b32c270058> in <module>
#       1 hist_new_model = new_model.history
# ----> 2 loss_values = hist_new_model['loss']
#       3 val_loss_values = hist_new_model['val_loss']
#       4 acc_values = hist_new_model['acc']
#       5 val_acc_values = hist_new_model['val_acc']
#
# TypeError: 'History' object is not subscriptable

# %%
# results_train = new_model.evaluate(X_train, y_train)
# results_test = new_model.evaluate(X_test, y_test)
# print(results_train, results_test)
# Out:
# 435/435 [==============================] - 49s 112ms/step
# 136/136 [==============================] - 15s 112ms/step
# [0.0026334957740129896, 1.0] [0.23705798681199125, 0.9852941176470589]

# %%
# predictions_transfer = new_model.predict(X_test)
# predictions_transfer = np.around(predictions_transfer)

# %%
from keras import metrics

model.compile(loss='mean_squared_error',
              optimizer='sgd',
              metrics=[metrics.mae, metrics.categorical_accuracy])

# %%
from keras.metrics import top_k_categorical_accuracy

# %%
top_k_categorical_accuracy(y_true, y_pred, k=5)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1658   try:
# -> 1659     c_op = c_api.TF_FinishOperation(op_desc)
#    1660   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Shape must be rank 2 but is rank 1 for 'in_top_k_2/InTopKV2' (op: 'InTopKV2') with input shapes: [2776], [], [].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-69d56b32d247> in <module>
# ----> 1 top_k_categorical_accuracy(y_true, y_pred, k=5)
#
# /anaconda3/lib/python3.7/site-packages/keras/metrics.py in top_k_categorical_accuracy(y_true, y_pred, k)
#      42
#      43 def top_k_categorical_accuracy(y_true, y_pred, k=5):
# ---> 44     return K.mean(K.in_top_k(y_pred, K.argmax(y_true, axis=-1), k), axis=-1)
#      45
#      46
#
# /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in in_top_k(predictions, targets, k)
#    3472         values of `predictions[i]`.
#    3473     """
# -> 3474     return tf.nn.in_top_k(predictions, targets, k)
#    3475
#    3476
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py in in_top_k(predictions, targets, k, name)
#    3816   """
#    3817   with ops.name_scope(name, "in_top_k"):
# -> 3818     return gen_nn_ops.in_top_kv2(predictions, targets, k, name=name)
#    3819
#    3820
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_nn_ops.py in in_top_kv2(predictions, targets, k, name)
#    4539   # Add nodes to the TensorFlow graph.
#    4540   _, _, _op = _op_def_lib._apply_op_helper(
# -> 4541         "InTopKV2", predictions=predictions, targets=targets, k=k, name=name)
#    4542   _result = _op.outputs[:]
#    4543   _inputs_flat = _op.inputs
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3298           input_types=input_types,
#    3299           original_op=self._default_original_op,
# -> 3300           op_def=op_def)
#    3301       self._create_op_helper(ret, compute_device=compute_device)
#    3302     return ret
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1821           op_def, inputs, node_def.attr)
#    1822       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1823                                 control_input_ops)
#    1824
#    1825     # Initialize self._outputs.
#
# /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1660   except errors.InvalidArgumentError as e:
#    1661     # Convert to ValueError for backwards compatibility.
# -> 1662     raise ValueError(str(e))
#    1663
#    1664   return c_op
#
# ValueError: Shape must be rank 2 but is rank 1 for 'in_top_k_2/InTopKV2' (op: 'InTopKV2') with input shapes: [2776], [], [].

# %%
new_model.save('inception_multiple_classes.h5')
